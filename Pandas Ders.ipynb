# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Dosyalari okumak icin read_csv read_excel tarzi konutlar kullaniliyor

# %%
data = pd.read_csv('Pokemon.csv')

# %%
data.head(6) # bastan 6 veriyi goster
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False

# %%
data.tail(8) #sondan 8 datayi goster
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 792      131       98     99           6       True
# 793      131       98     99           6       True
# 794       81       95     95           6       True
# 795      100      150     50           6       True
# ...

# %%
data['Type 1'] #belirtilen dataFrame icindeki verilere ulasma
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
data.loc[792] #belirtilen satir verilerine erisim
# Out:
# #                 716
# Name          Xerneas
# Type 1          Fairy
# Type 2            NaN
# Total             680
# HP                126
# Attack            131
# Defense            95
# Sp. Atk           131
# Sp. Def            98
# Speed              99
# Generation          6
# Legendary        True
# Name: 792, dtype: object

# %%
data['Type 1'] == "Fire" #Type i Fire olan verilere true digerlerine false yazar
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
ates = data['Type 1'] == "Fire"
ates2 = data['Type 2'] == "Fire"

# %%
data[ates | ates2] #datasi sadece ates olan verileri bize veriyor. Burada gosterilen duz cizgi or anlamina gelmektedir
# Out:
#        #                       Name Type 1  Type 2  Total  HP  Attack  \
# 4      4                 Charmander   Fire     NaN    309  39      52
# 5      5                 Charmeleon   Fire     NaN    405  58      64
# 6      6                  Charizard   Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X   Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y   Fire  Flying    634  78     104
# ..   ...                        ...    ...     ...    ...  ..     ...
# 730  662                Fletchinder   Fire  Flying    382  62      73
# 731  663                 Talonflame   Fire  Flying    499  78      81
# 735  667                     Litleo   Fire  Normal    369  62      50
# 736  668                     Pyroar   Fire  Normal    507  86      68
# 799  721                  Volcanion   Fire   Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 4         43       60       50     65           1      False
# ...

# %%
ates = data['Type 1'] == "Fire"
dragon = data['Type 2'] == "Dragon"

# %%
 data[ates & dragon]  #type1 i ates type 2 si dragon olan verileri getir. Burada gosterilen & ve anlami tasir
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7      130       85    100           1      False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
hiz120 = data["Speed"]>120 #hizi 120 den fazla olanlari yazdir

# %%
data[hiz120]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 109  101                  Electrode  Electric       NaN    480   60      50
# 146  135                    Jolteon  Electric       NaN    525   65      65
# 153  142                 Aerodactyl      Rock    Flying    515   80     105
# 154  142  AerodactylMega Aerodactyl      Rock    Flying    615   80     135
# 162  150                     Mewtwo   Psychic       NaN    680  106     110
# 163  150        MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150        MewtwoMega Mewtwo Y   Psychic       NaN    780  106     150
# ...

# %%
data['Type 1'].unique() #datanin type 1 i icinde kac tane farkli tur oldugunu bize ekrana yazan fonksiyon "unique()"
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
len(data['Type 1'].unique()) #yukarida elde ettigim sonucun sayisini veren fonksiyon
# Out:
# 18

# %%
data.set_index('Speed') #verinin index numarasini veri icindeki her hangi bir sutun yapabiliriz
# Out:
#          #                   Name   Type 1  Type 2  Total  HP  Attack  \
# Speed
# 45       1              Bulbasaur    Grass  Poison    318  45      49
# 60       2                Ivysaur    Grass  Poison    405  60      62
# 80       3               Venusaur    Grass  Poison    525  80      82
# 80       3  VenusaurMega Venusaur    Grass  Poison    625  80     100
# 65       4             Charmander     Fire     NaN    309  39      52
# ...    ...                    ...      ...     ...    ...  ..     ...
# 50     719                Diancie     Rock   Fairy    600  50     100
# 110    719    DiancieMega Diancie     Rock   Fairy    700  50     160
# 70     720    HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 80     720     HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 70     721              Volcanion     Fire   Water    600  80     110
#
#        Defense  Sp. Atk  Sp. Def  Generation  Legendary
# Speed
# ...

# %%
data.iloc[0] #0 index numarasina ait olan satirin verilerini yazdi. Burada "iloc" fonksiyonu yardimci oldu
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# Total               318
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
data = data.set_index('Name')

# %%
data.loc['Diancie'] #yeni index numarasi olarak kabuk edilne pokemon adini yazip ona ait verileri listeleme
# Out:
# #               719
# Type 1         Rock
# Type 2        Fairy
# Total           600
# HP               50
# Attack          100
# Defense         150
# Sp. Atk         100
# Sp. Def         150
# Speed            50
# Generation        6
# Legendary      True
# Name: Diancie, dtype: object

# %%
data.iloc[3:6] #3 ile 6 arasi degerler ekrana getirir
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
# Charmeleon             5   Fire     NaN    405  58      64       58       80
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False
# Charmeleon                  65     80           1      False

# %%
data.iloc[-1] #son veriyi goruruz
# Out:
# #               721
# Type 1         Fire
# Type 2        Water
# Total           600
# HP               80
# Attack          110
# Defense         120
# Sp. Atk         130
# Sp. Def          90
# Speed            70
# Generation        6
# Legendary      True
# Name: Volcanion, dtype: object

# %% [markdown]
# ## Pandas ile matematiksel islemler yapilabilir

# %%
data.head(2)
# Out:
#            # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur  1  Grass  Poison    318  45      49       49       65       65
# Ivysaur    2  Grass  Poison    405  60      62       63       80       80
#
#            Speed  Generation  Legendary
# Name
# Bulbasaur     45           1      False
# Ivysaur       60           1      False

# %%
data['Att-Def'] = (data['Attack']*2) + (data['Defense']*3) #yeni bir sutun olusturduk ve buraya verileri yazdik

# %%
data.head(6) #yeni satirimiz her yer isledi
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
# Charmeleon             5   Fire     NaN    405  58      64       58       80
#
#                        Sp. Def  Speed  Generation  Legendary  Att-Def
# Name
# Bulbasaur                   65     45           1      False      245
# Ivysaur                     80     60           1      False      313
# Venusaur                   100     80           1      False      413
# VenusaurMega Venusaur      120     80           1      False      569
# ...

# %%
data.columns #tum columns degerleri burada
# Out:
# Index(['#', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Att-Def'],
#       dtype='object')

# %%
data.index #index numarakari gozukur
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X',
#        'CharizardMega Charizard Y', 'Squirtle',
#        ...
#        'Noibat', 'Noivern', 'Xerneas', 'Yveltal', 'Zygarde50% Forme',
#        'Diancie', 'DiancieMega Diancie', 'HoopaHoopa Confined',
#        'HoopaHoopa Unbound', 'Volcanion'],
#       dtype='object', name='Name', length=800)

# %% [markdown]
# ### DataSetlerde bazen bos NaN degerler olur bunu "dropna" fonksiyonu ile kaldirmak mumkundur

# %%
data.head(30)
# Out:
#                             #  Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                   1   Grass  Poison    318  45      49       49
# Ivysaur                     2   Grass  Poison    405  60      62       63
# Venusaur                    3   Grass  Poison    525  80      82       83
# VenusaurMega Venusaur       3   Grass  Poison    625  80     100      123
# Charmander                  4    Fire     NaN    309  39      52       43
# Charmeleon                  5    Fire     NaN    405  58      64       58
# Charizard                   6    Fire  Flying    534  78      84       78
# CharizardMega Charizard X   6    Fire  Dragon    634  78     130      111
# CharizardMega Charizard Y   6    Fire  Flying    634  78     104       78
# Squirtle                    7   Water     NaN    314  44      48       65
# Wartortle                   8   Water     NaN    405  59      63       80
# Blastoise                   9   Water     NaN    530  79      83      100
# ...

# %% [markdown]
# #### Yukarida bazi degerler NaN olarak verilmis. Simdi onlari kaldiracagiz

# %%
data = data.dropna()

# %%
data.head(30)
# Out:
#                             #  Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Bulbasaur                   1   Grass  Poison    318   45      49       49
# Ivysaur                     2   Grass  Poison    405   60      62       63
# Venusaur                    3   Grass  Poison    525   80      82       83
# VenusaurMega Venusaur       3   Grass  Poison    625   80     100      123
# Charizard                   6    Fire  Flying    534   78      84       78
# CharizardMega Charizard X   6    Fire  Dragon    634   78     130      111
# CharizardMega Charizard Y   6    Fire  Flying    634   78     104       78
# Butterfree                 12     Bug  Flying    395   60      45       50
# Weedle                     13     Bug  Poison    195   40      35       30
# Kakuna                     14     Bug  Poison    205   45      25       50
# Beedrill                   15     Bug  Poison    395   65      90       40
# ...

# %% [markdown]
# ### Goruldugu gibi tum NaN degerler silindi ve # numaralari da duzenli bir sekilde tekrar yazildi

# %%
data['Speed'].astype("float") #int olan data turunu float'a cevirdik
# Out:
# Name
# Bulbasaur                 45.0
# Ivysaur                   60.0
# Venusaur                  80.0
# VenusaurMega Venusaur     80.0
# Charizard                100.0
#                          ...
# Diancie                   50.0
# DiancieMega Diancie      110.0
# HoopaHoopa Confined       70.0
# HoopaHoopa Unbound        80.0
# Volcanion                 70.0
# Name: Speed, Length: 414, dtype: float64
